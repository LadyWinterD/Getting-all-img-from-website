# %%
import requests
from bs4 import BeautifulSoup
import re
import time
import csv

url="http://www.microanalytix.co.nz/"
r=requests.get(url)
soup=BeautifulSoup(r.text,'html.parser')

category_list=soup.find_all('ul', class_="list")

#print(soup.prettify())
urls = list(map(lambda k: k.a['href'], soup.find_all('ul', class_="list")))
#print(urls)
#type(urls)
links = []
for item in urls:
    print(item)
print(urls)
# Out:
# /filtration
# /advantec
# ['/filtration', '/advantec']

# %%
import requests
from bs4 import BeautifulSoup
import re
import time
import csv

url="http://www.microanalytix.co.nz/"
r=requests.get(url)
soup=BeautifulSoup(r.text,'html.parser')

#category_list=soup.find_all('li', class_="inactive")

#print(soup.prettify())
urls = list(map(lambda k: k.a['href'], soup.find_all('li', class_="inactive")))
#print(urls)
microAnalytix = 'http://www.microanalytix.co.nz'
fullUrls = []
for i in range(len(urls)):
    urls[i] = microAnalytix + urls[i]
fullUrls = urls
print(fullUrls)
for i in fullUrls:
    print(i)
    url=i
    r=requests.get(url)
    soup=BeautifulSoup(r.text,'html.parser')
    subcategory_list = list(map(lambda k: k.a['href'], soup.find_all('h2', class_="title")))
    for i in range(len(subcategory_list)):
        subcategory_list[i] = microAnalytix + subcategory_list[i]
        Fullsubcategory_list = subcategory_list
    print(Fullsubcategory_list)
# Out:
# ['http://www.microanalytix.co.nz/filtration', 'http://www.microanalytix.co.nz/chromatography', 'http://www.microanalytix.co.nz/water-purification', 'http://www.microanalytix.co.nz/laboratory-equipment', 'http://www.microanalytix.co.nz/filtration-equipment', 'http://www.microanalytix.co.nz/ph-buffers-standards', 'http://www.microanalytix.co.nz/plasticware', 'http://www.microanalytix.co.nz/glassware', 'http://www.microanalytix.co.nz/optifix-dispensers', 'http://www.microanalytix.co.nz/sterile-sample-bags', 'http://www.microanalytix.co.nz/gloves-2', 'http://www.microanalytix.co.nz/sample-bags-gloves', 'http://www.microanalytix.co.nz/sampling-equipment', 'http://www.microanalytix.co.nz/advantec', 'http://www.microanalytix.co.nz/ge-whatman', 'http://www.microanalytix.co.nz/jg-finneran', 'http://www.microanalytix.co.nz/brady', 'http://www.microanalytix.co.nz/microscience']
# http://www.microanalytix.co.nz/filtration
# ...

# %%
fullitemDetail = []
for i in Fullsubcategory_list:
    print(i)
    url=i
    r=requests.get(url)
    soup=BeautifulSoup(r.text,'html.parser')
    itemDetail = list(map(lambda k: k.a['href'], soup.find_all('div', class_="picture")))
    for i in range(len(itemDetail)):
        itemDetail[i] = microAnalytix + itemDetail[i]
        fullitemDetail= itemDetail
    print(fullitemDetail)
# Out:
# http://www.microanalytix.co.nz/scoops
# ['http://www.microanalytix.co.nz/scoops-stainless-steel-b01344wa']
# http://www.microanalytix.co.nz/sludge-judges
# ['http://www.microanalytix.co.nz/bottom-section-with-valve-5-ft-153-m-', 'http://www.microanalytix.co.nz/bottom-section-with-valve-5-ft-153-m-3', 'http://www.microanalytix.co.nz/cleaning-brush', 'http://www.microanalytix.co.nz/nasco-sludge-nabber', 'http://www.microanalytix.co.nz/settleometer-kit', 'http://www.microanalytix.co.nz/the-sludge-judge-15-ft-460-m', 'http://www.microanalytix.co.nz/the-sludge-judge-ii-large-capacity', 'http://www.microanalytix.co.nz/the-sludge-judge-ultra-super-strong']
# http://www.microanalytix.co.nz/asbestos-sampling
# ['http://www.microanalytix.co.nz/cowls-filters', 'http://www.microanalytix.co.nz/ri-oils', 'http://www.microanalytix.co.nz/slides-cover-slips', 'http://www.microanalytix.co.nz/pumps-2']

# %%
for options in bumblebeeMind:
    if options[i] == 'Loin King':
        print('&#9829;&#9829;&#9829;')
    elif options[i] == 'Overcooked':
        print('&#9829;&#9829;')
    elif options[i] == 'Rainbow 6' or options[i] == 'Chernobyl':
        print('&#9829;')
    else:
        print('See my bumblebee tonight')
# Out:
# See my bumblebee tonight
# See my bumblebee tonight
# See my bumblebee tonight

# %%
import requests
from bs4 import BeautifulSoup
import re
import time
import csv

url="http://www.microanalytix.co.nz/manufacturer/all"
r=requests.get(url)
soup=BeautifulSoup(r.text,'html.parser')

brandName=soup.find_all('h2', class_="title")

#print(soup.prettify())
urls = list(map(lambda k: k.a['href'], soup.find_all('h2', class_="title")))
#print(urls)
#type(urls)
linksOfBrand = []
microAnalytix = 'http://www.microanalytix.co.nz'
for item in urls:
    print(item)
    item= microAnalytix + item
    linksOfBrand.append(item)
    print(linksOfBrand)
# Out:
# /advantec
# ['http://www.microanalytix.co.nz/advantec']
# /ge-whatman
# ['http://www.microanalytix.co.nz/advantec', 'http://www.microanalytix.co.nz/ge-whatman']
# /jg-finneran
# ['http://www.microanalytix.co.nz/advantec', 'http://www.microanalytix.co.nz/ge-whatman', 'http://www.microanalytix.co.nz/jg-finneran']
# /brady
# ['http://www.microanalytix.co.nz/advantec', 'http://www.microanalytix.co.nz/ge-whatman', 'http://www.microanalytix.co.nz/jg-finneran', 'http://www.microanalytix.co.nz/brady']
# /microscience
# ['http://www.microanalytix.co.nz/advantec', 'http://www.microanalytix.co.nz/ge-whatman', 'http://www.microanalytix.co.nz/jg-finneran', 'http://www.microanalytix.co.nz/brady', 'http://www.microanalytix.co.nz/microscience']
# /suez
# ...

# %%
import requests
from bs4 import BeautifulSoup
import re
import time
import csv

url="http://www.microanalytix.co.nz/manufacturer/all"
r=requests.get(url)
soup=BeautifulSoup(r.text,'html.parser')

brandName=soup.find_all('h2', class_="title")

#print(soup.prettify())
urls = list(map(lambda k: k.a['href'], soup.find_all('h2', class_="title")))
#print(urls)
#type(urls)
linksOfBrand = []
microAnalytix = 'http://www.microanalytix.co.nz'
for item in urls:
    #print(item)
    item= microAnalytix + item
    linksOfBrand.append(item)
    #print(linksOfBrand)
for product in linksOfBrand:
    url = product
    r=requests.get(url)
    soup=BeautifulSoup(r.text,'html.parser')
    itemsLink = list(map(lambda k: k.a['href'], soup.find_all('h2', class_="product-title")))
    #print(itemsLink)
    detailsOfItems = []
    ##get the link of the brand
    
    
    
    for i in itemsLink:
        i = microAnalytix + i
        detailsOfItems.append(i)
        #print(detailsOfItems)
        for i in detailsOfItems:
            url = i
            r=requests.get(url)
            soup=BeautifulSoup(r.text,'html.parser')
            imgLink = list(map(lambda k: k.img['src'], soup.find_all('div', class_="picture")))
            print(imgLink)
if
# Out:
# ['http://www.microanalytix.co.nz/content/images/thumbs/0001842_25mm-ca-syringe-filter-045um-25cs045as_300.jpeg']
# ['http://www.microanalytix.co.nz/content/images/thumbs/0001842_25mm-ca-syringe-filter-045um-25cs045as_300.jpeg']
# ['http://www.microanalytix.co.nz/content/images/thumbs/0003879_3-piece-monitors-37as345bs_300.jpeg']
# ['http://www.microanalytix.co.nz/content/images/thumbs/0001842_25mm-ca-syringe-filter-045um-25cs045as_300.jpeg']
# ['http://www.microanalytix.co.nz/content/images/thumbs/0003879_3-piece-monitors-37as345bs_300.jpeg']
# ['http://www.microanalytix.co.nz/content/images/thumbs/0012078_advantec-antibiotic-paper-assay-49005010_300.jpeg']
# ['http://www.microanalytix.co.nz/content/images/thumbs/0001842_25mm-ca-syringe-filter-045um-25cs045as_300.jpeg']
# ['http://www.microanalytix.co.nz/content/images/thumbs/0003879_3-piece-monitors-37as345bs_300.jpeg']
# ...
